# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
# Save path to data set in a variable
data = "../Resources/cities.csv"

# %%
# Use Pandas to read data
data_file_df = pd.read_csv(data)
data_file_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
data_file_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, title="City Latitude vs. Max Temperature (01/05/17)")
plt.tight_layout()
#plt.savefig("/PandasImage/Lat.Temp.png")
#plt.savefig("../Resources/Lat.Temp.png")
plt.show()

# %%
data_file_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, title="City Latitude vs. Cloudiness (01/05/17)")
plt.tight_layout()
#plt.savefig("../Resources/Lat.Cloudiness.png")
plt.show()

# %%
data_file_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, title="City Latitude vs. Humidity (01/05/17)")
plt.tight_layout()
#plt.savefig("../Resources/Lat.Humidity.png")
plt.show()

# %%
data_file_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, title="City Latitude vs. Wind Speed (01/05/17)")
plt.tight_layout()
#plt.savefig("../Resources/Lat.Wind Speed.png")
plt.show()
